# %%
# Import Necesary Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load Dataset
players = pd.read_csv('./Data/player_predictions.csv')
goalkeepers = pd.read_csv('./Data/goalkeeper_predictions.csv')
roles = pd.read_csv('./Data/player_role_clusters.csv')

# %%
players.head()
# Out:
#            id         name   age    nationality  height weight        team  \
# 0  3581239250     J. Bamba  29.0  Côte d'Ivoire  175 cm  72 kg  Celta Vigo
# 1  2607061911   Lucas Rosa  25.0         Brazil  176 cm  68 kg  Valladolid
# 2   206332792  Abdulay Bah  19.0   Sierra Leone  195 cm  80 kg  Valladolid
# 3   796815709    A. Tuhami  30.0        Morocco  173 cm  69 kg  Valladolid
# 4  3804650568     M. Sylla  31.0        Senegal  184 cm  84 kg  Valladolid
#
#     league  season  minutes_played  ... shots_score  assists_score  \
# 0  La Liga    2024           815.0  ...    5.043507       5.677778
# 1  La Liga    2024          1890.0  ...    3.711096       5.093275
# 2  La Liga    2024           865.0  ...    4.631408       4.582773
# 3  La Liga    2024           960.0  ...    7.276587       4.688973
# 4  La Liga    2024           913.0  ...    6.087062       6.532798
#
#    tackles_score  duels_score  dribbles_score  passes_score  foul_score  \
# ...

# %%
goalkeepers.head()
# Out:
#            id              name   age nationality  height weight        team  \
# 0  3209365995         Rui Silva  31.0    Portugal  191 cm  91 kg  Real Betis
# 1  3686317755           K. Hein  23.0     Estonia  193 cm  86 kg  Valladolid
# 2   428742163  G. Mamardashvili  25.0     Georgia  197 cm  90 kg    Valencia
# 3  2432118490            Sivera  29.0       Spain  184 cm  75 kg      Alaves
# 4  1467762063       Joan García  24.0       Spain  191 cm  79 kg    Espanyol
#
#     league  season  minutes_played  ... shots_score  assists_score  \
# 0  La Liga    2024          1350.0  ...         NaN            NaN
# 1  La Liga    2024          1980.0  ...         NaN            NaN
# 2  La Liga    2024          1440.0  ...         NaN            NaN
# 3  La Liga    2024          1584.0  ...         NaN            NaN
# 4  La Liga    2024          1980.0  ...         NaN            NaN
#
#    tackles_score  duels_score  dribbles_score  passes_score  foul_score  \
# ...
